# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados_csv = pd.read_csv('/content/drive/MyDrive/Faculdade/4° Ano/1° Semestre/Programação Paralela e Concorrente I/trabalho_prático/Dados/dataset_00_1000_sem_virg.csv', encoding="utf8")
dados_csv

# %%
dados_excel = pd.read_excel('/content/drive/MyDrive/Faculdade/4° Ano/1° Semestre/Programação Paralela e Concorrente I/trabalho_prático/Dados/dados_teste.xlsx')
dados_excel

# %%
dados_excel.to_csv (r'/content/drive/MyDrive/Faculdade/4° Ano/1° Semestre/Programação Paralela e Concorrente I/trabalho_prático/Dados/test_date.csv', index = None, header=True)
